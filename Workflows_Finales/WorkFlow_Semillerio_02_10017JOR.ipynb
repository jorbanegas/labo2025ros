# %% [markdown]
# # 8 WorkFlow  Semillerio

# %% [markdown]
# ### 8.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 8.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %% [markdown]
# *  Si usted eligió modalidad *Gerencial* entonces NO debe modificar nada, su liderazgo logró que otras trabajaron por usted
# *  Si usted eligió modalidad de *Analista Junior*, entonces donde dice archivo="gerencial_competencia_2025.csv.gz"  lo debe cambiar por  archivo="analistajr_competencia_2025.csv.gz"
# *  Si usted eligió modalidad *Analista Senior*,  ya se las ingenierá SIN preguntar !

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/labo1r"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 8.3  Workflow Semillerio

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Jul 20 03:42:15 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  659644 35.3 1454477    77.7 1433621  76.6
# Vcells 1225712  9.4 8388608    64.0 1975128  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %% [markdown]
# ### Usted DEBE ambiar "PARAM experimento" cada vez que desee correr un nuevo experimento

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 100003

PARAM$experimento <- 10017
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 8.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 8.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 8.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 8.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# meses que me interesan para el ajuste de variables monetarias
vfoto_mes <- c(
  202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107, 202108, 202109
)

# %%
# los valores que siguen fueron calculados por alumnos

# momento 1.0  31-dic-2020 a las 23:59
vIPC <- c(
  1.2118694724, 1.1881073259,
  1.1693969743, 1.1375456949, 1.1065619600,
  1.0681100000, 1.0370000000, 1.0000000000,
  0.9680542110, 0.9344152616, 0.8882274350,
  0.8532444140, 0.8251880213, 0.8003763543,
  0.7763107219, 0.7566381305, 0.7289384687
)

vdolar_blue <- c(
  126.236842, 125.857143,
  130.782609, 133.400000, 137.954545,
  170.619048, 160.400000, 153.052632,
  157.900000, 149.380952, 143.615385,
  146.250000, 153.550000, 162.000000,
  178.478261, 180.878788, 184.357143
)

vdolar_oficial <- c(
   70.047895,  72.520952,
   75.324286,  77.488500,  79.430909,
   83.134762,  85.484737,  88.181667,
   91.474000,  93.997778,  96.635909,
   98.526000,  99.613158, 100.619048,
  101.619048, 102.569048, 103.781818
)

vUVA <- c(
  1.1770808941405335, 1.1570338657445522,
  1.1388769475653255, 1.1156993751209352, 1.093638313080772,
  1.0657171590878205, 1.0362173587708712, 1.0,
  0.9669867858358365, 0.9323750098728378, 0.8958202912590305,
  0.8631993702994263, 0.8253893405524657, 0.7928918905364516,
  0.7666323845128089, 0.7428976357662823, 0.721615762047849
)

# %%
tb_indices <- as.data.table( list(
  "IPC" = vIPC,
  "dolar_blue" = vdolar_blue,
  "dolar_oficial" = vdolar_oficial,
  "UVA" = vUVA
  )
)

tb_indices[[ 'foto_mes' ]] <- vfoto_mes

tb_indices
# Out:
#    IPC       dolar_blue dolar_oficial UVA       foto_mes
# 1  1.2118695 126.2368    70.04789     1.1770809 202005
# 2  1.1881073 125.8571    72.52095     1.1570339 202006
# 3  1.1693970 130.7826    75.32429     1.1388769 202007
# 4  1.1375457 133.4000    77.48850     1.1156994 202008
# 5  1.1065620 137.9545    79.43091     1.0936383 202009
# 6  1.0681100 170.6190    83.13476     1.0657172 202010
# 7  1.0370000 160.4000    85.48474     1.0362174 202011
# 8  1.0000000 153.0526    88.18167     1.0000000 202012
# 9  0.9680542 157.9000    91.47400     0.9669868 202101
# 10 0.9344153 149.3810    93.99778     0.9323750 202102
# 11 0.8882274 143.6154    96.63591     0.8958203 202103
# 12 0.8532444 146.2500    98.52600     0.8631994 202104
# 13 0.8251880 153.5500    99.61316     0.8253893 202105
# 14 0.8003764 162.0000   100.61905     0.7928919 202106
# 15 0.7763107 178.4783   101.61905     0.7666324 202107
# 16 0.7566381 180.8788   102.56905     0.7428976 202108
# 17 0.7289385 184.3571   103.78182     0.7216158 202109

# %%
drift_UVA <- function(campos_monetarios) {
  cat( "inicio drift_UVA()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.UVA,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_UVA()\n")
}

# %%
drift_dolar_oficial <- function(campos_monetarios) {
  cat( "inicio drift_dolar_oficial()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_oficial,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_oficial()\n")
}

# %%
drift_dolar_blue <- function(campos_monetarios) {
  cat( "inicio drift_dolar_blue()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_blue,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_blue()\n")
}

# %%
drift_deflacion <- function(campos_monetarios) {
  cat( "inicio drift_deflacion()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.IPC,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_deflacion()\n")
}

# %%
drift_rank_simple <- function(campos_drift) {

  cat( "inicio drift_rank_simple()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_rank") :=
      (frank(get(campo), ties.method = "random") - 1) / (.N - 1), by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat( "fin drift_rank_simple()\n")
}

# %%
# El cero se transforma en cero
# los positivos se rankean por su lado
# los negativos se rankean por su lado

drift_rank_cero_fijo <- function(campos_drift) {

  cat( "inicio drift_rank_cero_fijo()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[get(campo) == 0, paste0(campo, "_rank") := 0]
    dataset[get(campo) > 0, paste0(campo, "_rank") :=
      frank(get(campo), ties.method = "random") / .N, by = list(foto_mes)]

    dataset[get(campo) < 0, paste0(campo, "_rank") :=
      -frank(-get(campo), ties.method = "random") / .N, by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat("\n")
  cat( "fin drift_rank_cero_fijo()\n")
}

# %%
drift_estandarizar <- function(campos_drift) {

  cat( "inicio drift_estandarizar()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_normal") :=
      (get(campo) -mean(campo, na.rm=TRUE)) / sd(get(campo), na.rm=TRUE),
      by = list(foto_mes)]

    dataset[, (campo) := NULL]
  }
  cat( "fin drift_estandarizar()\n")
}

# %%
# por como armé los nombres de campos,
#  estos son los campos que expresan variables monetarias
campos_monetarios <- colnames(dataset)
campos_monetarios <- campos_monetarios[campos_monetarios %like%
  "^(m|Visa_m|Master_m|vm_m)"]

campos_monetarios
# Out:
#  [1] "mrentabilidad"           "mrentabilidad_annual"
#  [3] "mcomisiones"             "mactivos_margen"
#  [5] "mpasivos_margen"         "mcuenta_corriente"
#  [7] "mcaja_ahorro"            "mcuentas_saldo"
#  [9] "mtarjeta_visa_consumo"   "mtarjeta_master_consumo"
# [11] "mprestamos_personales"   "mpayroll"
# [13] "Master_mpagominimo"      "Visa_mpagominimo"

# %%
# ejecuto el Data Drifting
setorder( dataset, numero_de_cliente, foto_mes )


PARAM$DR$metodo <- "deflacion"

switch(PARAM$DR$metodo,
  "ninguno"        = cat("No hay correccion del data drifting"),
  "rank_simple"    = drift_rank_simple(campos_monetarios),
  "rank_cero_fijo" = drift_rank_cero_fijo(campos_monetarios),
  "deflacion"      = drift_deflacion(campos_monetarios),
  "dolar_blue"     = drift_dolarblue(campos_monetarios),
  "dolar_oficial"  = drift_dolaroficial(campos_monetarios),
  "UVA"            = drift_UVA(campos_monetarios),
  "estandarizar"   = drift_estandarizar(campos_monetarios)
)
# Out:
# inicio drift_deflacion()
# fin drift_deflacion()

# %%
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"

# %% [markdown]
# #### 8.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
if( !require("lubridate")) install.packages("lubridate", repos = "http://cran.us.r-project.org")
require("lubridate")
# Out:
# Loading required package: lubridate
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# %%
# Esta es la parte que los alumnos deben desplegar todo su ingenio
# Agregar aqui sus PROPIAS VARIABLES manuales

AgregarVariables_IntraMes <- function(dataset) {
  cat( "inicio AgregarVariables_IntraMes()\n")
  gc(verbose= FALSE)
  # INICIO de la seccion donde se deben hacer cambios con variables nuevas

  # el mes 1,2, ..12
  if( atributos_presentes( c("foto_mes") ))
    dataset[, kmes := foto_mes %% 100]

  # creo un ctr_quarter que tenga en cuenta cuando
  # los clientes hace 3 menos meses que estan
  # ya que seria injusto considerar las transacciones medidas en menor tiempo
  if( atributos_presentes( c("ctrx_quarter") ))
    dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[
      cliente_antiguedad == 3,
      ctrx_quarter_normalizado := ctrx_quarter * 1.2
    ]


  if(atributos_presentes(c("ctarjeta_debito_transacciones","ctarjeta_visa_transacciones","ctarjeta_master_transacciones",
    "cpagodeservicios","cpagomiscuentas","cforex","ctransferencias_recibidas",
    "ctransferencias_emitidas","cextraccion_autoservicio","ccheques_depositados",
    "ccallcenter_transacciones","chomebanking_transacciones","ccajas_transacciones",
    "ccajas_depositos","catm_trx","catm_trx_other","cmobile_app_trx","Master_cconsumos",
    "Master_cadelantosefectivo","Visa_cconsumos","Visa_cadelantosefectivo")))
    dataset[, cantidad_total_transacciones :=
      ifelse( is.na(ctarjeta_debito_transacciones), 0, ctarjeta_debito_transacciones) +
      ifelse( is.na(ctarjeta_visa_transacciones), 0, ctarjeta_visa_transacciones) +
      ifelse( is.na(ctarjeta_master_transacciones), 0, ctarjeta_master_transacciones) +
      ifelse( is.na(cpagodeservicios), 0, cpagodeservicios) +
      ifelse( is.na(cpagomiscuentas), 0, cpagomiscuentas) +
      ifelse( is.na(cforex), 0, cforex) +
      ifelse( is.na(ctransferencias_recibidas), 0, ctransferencias_recibidas) +
      ifelse( is.na(ctransferencias_emitidas), 0, ctransferencias_emitidas) +
      ifelse( is.na(cextraccion_autoservicio), 0, cextraccion_autoservicio) +
      ifelse( is.na(ccheques_depositados), 0, ccheques_depositados) +
      ifelse( is.na(ccallcenter_transacciones), 0, ccallcenter_transacciones) +
      ifelse( is.na(chomebanking_transacciones), 0, chomebanking_transacciones) +
      ifelse( is.na(ccajas_transacciones), 0, ccajas_transacciones) +
      ifelse( is.na(ccajas_depositos), 0, ccajas_depositos) +
      ifelse( is.na(catm_trx), 0, catm_trx) +
      ifelse( is.na(catm_trx_other), 0, catm_trx_other) +
      ifelse( is.na(cmobile_app_trx), 0, cmobile_app_trx) +
      ifelse( is.na(Master_cconsumos), 0, Master_cconsumos) +
      ifelse( is.na(Master_cadelantosefectivo), 0, Master_cadelantosefectivo) +
      ifelse( is.na(Visa_cconsumos), 0, Visa_cconsumos) +
      ifelse( is.na(Visa_cadelantosefectivo), 0, Visa_cadelantosefectivo)
    ]

   if(atributos_presentes(c("foto_mes")))
    dataset[,foto_mes_formato_fecha := as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))]

  #dataset$foto_mes_formato_fecha <<- as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))

  if(atributos_presentes(c("cantidad_total_transacciones"))){
   auxiliarmenos1 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha, cantidad_total_transacciones)]
   auxiliarmenos2 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha,cantidad_total_transacciones)]
   # auxiliarmenos1$foto_mes_formato_fecha <- as.Date(auxiliarmenos1$foto_mes_formato_fecha)
   # auxiliarmenos2$foto_mes_formato_fecha <- as.Date(auxiliarmenos2$foto_mes_formato_fecha)
   auxiliarmenos1$foto_mes_formato_fecha <- auxiliarmenos1$foto_mes_formato_fecha  %m-%  months(1)
   auxiliarmenos2$foto_mes_formato_fecha <- auxiliarmenos2$foto_mes_formato_fecha %m-% months(2)
   auxiliarmenos1$codigo <- paste(auxiliarmenos1$numero_de_cliente,auxiliarmenos1$foto_mes_formato_fecha,sep='-')
   auxiliarmenos2$codigo <- paste(auxiliarmenos2$numero_de_cliente,auxiliarmenos2$foto_mes_formato_fecha,sep='-')

   dataset[, codigo := paste(numero_de_cliente, foto_mes_formato_fecha, sep='-') ]

   dataset[ auxiliarmenos1,
            on = "codigo",
            transaccionesmenos1 := i.cantidad_total_transacciones ]

   dataset[ auxiliarmenos2,
            on = "codigo",
            transaccionesmenos2 := i.cantidad_total_transacciones ]

   dataset[, cantidad_total_transacciones_quarter := rowSums(cbind(cantidad_total_transacciones +
    transaccionesmenos1 + transaccionesmenos2),na.rm=T) ]

   dataset[, codigo := NULL ]
   dataset[, transaccionesmenos1 := NULL ]
   dataset[, transaccionesmenos2 := NULL ]
   dataset[, foto_mes_formato_fecha := NULL ]
   rm(auxiliarmenos1)
   rm(auxiliarmenos2)
  }

  if( atributos_presentes( c("cantidad_total_transacciones_quarter") ))
    dataset[, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 5]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 2]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 3, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 1.2]

  # variable extraida de una tesis de maestria de Irlanda
  if( atributos_presentes( c("mpayroll", "cliente_edad") ))
    dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

  # se crean los nuevos campos para MasterCard  y Visa,
  #  teniendo en cuenta los NA's
  # varias formas de combinar Visa_status y Master_status
  if( atributos_presentes( c("Master_status", "Visa_status") ))
  {
    dataset[, vm_status01 := pmax(Master_status, Visa_status, na.rm = TRUE)]
    dataset[, vm_status02 := Master_status + Visa_status]

    dataset[, vm_status03 := pmax(
      ifelse(is.na(Master_status), 10, Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status)
    )]

    dataset[, vm_status04 := ifelse(is.na(Master_status), 10, Master_status)
      + ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status05 := ifelse(is.na(Master_status), 10, Master_status)
      + 100 * ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status06 := ifelse(is.na(Visa_status),
      ifelse(is.na(Master_status), 10, Master_status),
      Visa_status
    )]

    dataset[, mv_status07 := ifelse(is.na(Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status),
      Master_status
    )]
  }


  # combino MasterCard y Visa
  if( atributos_presentes( c("Master_mfinanciacion_limite", "Visa_mfinanciacion_limite") ))
    dataset[, vm_mfinanciacion_limite := rowSums(cbind(Master_mfinanciacion_limite, Visa_mfinanciacion_limite), na.rm = TRUE)]

  if( atributos_presentes( c("Master_Fvencimiento", "Visa_Fvencimiento") ))
    dataset[, vm_Fvencimiento := pmin(Master_Fvencimiento, Visa_Fvencimiento, na.rm = TRUE)]

  if( atributos_presentes( c("Master_Finiciomora", "Visa_Finiciomora") ))
    dataset[, vm_Finiciomora := pmin(Master_Finiciomora, Visa_Finiciomora, na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldototal", "Visa_msaldototal") ))
    dataset[, vm_msaldototal := rowSums(cbind(Master_msaldototal, Visa_msaldototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldopesos", "Visa_msaldopesos") ))
    dataset[, vm_msaldopesos := rowSums(cbind(Master_msaldopesos, Visa_msaldopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldodolares", "Visa_msaldodolares") ))
    dataset[, vm_msaldodolares := rowSums(cbind(Master_msaldodolares, Visa_msaldodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumospesos", "Visa_mconsumospesos") ))
    dataset[, vm_mconsumospesos := rowSums(cbind(Master_mconsumospesos, Visa_mconsumospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumosdolares", "Visa_mconsumosdolares") ))
    dataset[, vm_mconsumosdolares := rowSums(cbind(Master_mconsumosdolares, Visa_mconsumosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mlimitecompra", "Visa_mlimitecompra") ))
    dataset[, vm_mlimitecompra := rowSums(cbind(Master_mlimitecompra, Visa_mlimitecompra), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantopesos", "Visa_madelantopesos") ))
    dataset[, vm_madelantopesos := rowSums(cbind(Master_madelantopesos, Visa_madelantopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantodolares", "Visa_madelantodolares") ))
    dataset[, vm_madelantodolares := rowSums(cbind(Master_madelantodolares, Visa_madelantodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fultimo_cierre", "Visa_fultimo_cierre") ))
    dataset[, vm_fultimo_cierre := pmax(Master_fultimo_cierre, Visa_fultimo_cierre, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagado", "Visa_mpagado") ))
    dataset[, vm_mpagado := rowSums(cbind(Master_mpagado, Visa_mpagado), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagospesos", "Visa_mpagospesos") ))
    dataset[, vm_mpagospesos := rowSums(cbind(Master_mpagospesos, Visa_mpagospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagosdolares", "Visa_mpagosdolares") ))
    dataset[, vm_mpagosdolares := rowSums(cbind(Master_mpagosdolares, Visa_mpagosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fechaalta", "Visa_fechaalta") ))
    dataset[, vm_fechaalta := pmax(Master_fechaalta, Visa_fechaalta, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumototal", "Visa_mconsumototal") ))
    dataset[, vm_mconsumototal := rowSums(cbind(Master_mconsumototal, Visa_mconsumototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cconsumos", "Visa_cconsumos") ))
    dataset[, vm_cconsumos := rowSums(cbind(Master_cconsumos, Visa_cconsumos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cadelantosefectivo", "Visa_cadelantosefectivo") ))
    dataset[, vm_cadelantosefectivo := rowSums(cbind(Master_cadelantosefectivo, Visa_cadelantosefectivo), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagominimo", "Visa_mpagominimo") ))
    dataset[, vm_mpagominimo := rowSums(cbind(Master_mpagominimo, Visa_mpagominimo), na.rm = TRUE)]

  # a partir de aqui juego con la suma de Mastercard y Visa
  if( atributos_presentes( c("Master_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Master_mlimitecompra := Master_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("Visa_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Visa_mlimitecompra := Visa_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldototal", "vm_mlimitecompra") ))
    dataset[, vmr_msaldototal := vm_msaldototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_mlimitecompra") ))
    dataset[, vmr_msaldopesos := vm_msaldopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_msaldototal") ))
    dataset[, vmr_msaldopesos2 := vm_msaldopesos / vm_msaldototal]

  if( atributos_presentes( c("vm_msaldodolares", "vm_mlimitecompra") ))
    dataset[, vmr_msaldodolares := vm_msaldodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldodolares", "vm_msaldototal") ))
    dataset[, vmr_msaldodolares2 := vm_msaldodolares / vm_msaldototal]

  if( atributos_presentes( c("vm_mconsumospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumospesos := vm_mconsumospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumosdolares := vm_mconsumosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantopesos", "vm_mlimitecompra") ))
    dataset[, vmr_madelantopesos := vm_madelantopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantodolares", "vm_mlimitecompra") ))
    dataset[, vmr_madelantodolares := vm_madelantodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagado", "vm_mlimitecompra") ))
    dataset[, vmr_mpagado := vm_mpagado / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mpagospesos := vm_mpagospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mpagosdolares := vm_mpagosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumototal", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumototal := vm_mconsumototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagominimo", "vm_mlimitecompra") ))
    dataset[, vmr_mpagominimo := vm_mpagominimo / vm_mlimitecompra]

  # Aqui debe usted agregar sus propias nuevas variables

 # 1. Relación antigüedad-normalizada
  if(atributos_presentes(c("cliente_antiguedad","kmes")))
    dataset[, tenure_norm := cliente_antiguedad / (kmes + 1e-6)]

  # 2. Velocidad de apertura de productos
  if(atributos_presentes(c("cproductos","cliente_antiguedad")))
    dataset[, prod_per_month := cproductos / (cliente_antiguedad + 1e-6)]

  # 3. Tasa de uso intensivo de descubierto
  if(atributos_presentes(c("cdescubierto_preacordado","ctrx_quarter")))
    dataset[, overdraft_per_trx := cdescubierto_preacordado / (ctrx_quarter + 1e-6)]

  # 4. Preferencia canal remoto vs presencial
  if(atributos_presentes(c("ccallcenter_transacciones","chomebanking_transacciones")))
    dataset[, call_vs_home_ratio := ccallcenter_transacciones / (chomebanking_transacciones + 1e-6)]

  # 5. Desagregación de share de canales (pct sobre total trimestral)
  if(atributos_presentes(c("ctrx_quarter","ccallcenter_transacciones")))
    dataset[, pct_cc_trx := ccallcenter_transacciones / (ctrx_quarter + 1e-6)]
  if(atributos_presentes(c("ctrx_quarter","chomebanking_transacciones")))
    dataset[, pct_hb_trx := chomebanking_transacciones / (ctrx_quarter + 1e-6)]
  if(atributos_presentes(c("ctrx_quarter","cpayroll_trx")))
    dataset[, pct_pay_trx := cpayroll_trx / (ctrx_quarter + 1e-6)]

  # 6. Diferencia de edad vs antigüedad
  if(atributos_presentes(c("cliente_edad","cliente_antiguedad")))
    dataset[, age_minus_tenure := cliente_edad - cliente_antiguedad]

  # 7. Flag “nuevo y activo”
  if(atributos_presentes(c("cliente_antiguedad","ctrx_quarter","ctrx_quarter_normalizado"))) {
    thr <- dataset[, quantile(ctrx_quarter_normalizado, 0.75, na.rm = TRUE)]
    dataset[, new_high_trx := as.integer(cliente_antiguedad <= 3 & ctrx_quarter > thr)]
  }

  # 8. Interacción producto–comisión de mantenimiento
  if(atributos_presentes(c("cproductos","ccomisiones_mantenimiento")))
    dataset[, prod_x_maint_fee := cproductos * ccomisiones_mantenimiento]

  # 9. Cluster transaccional (KMeans sobre canales)
  if(atributos_presentes(c("ccallcenter_transacciones","chomebanking_transacciones","cpayroll_trx"))) {
    # Extraer datos y reemplazar NAs
    dt_tmp <- dataset[, .(ccallcenter_transacciones, chomebanking_transacciones, cpayroll_trx)]
    # Convertir a matriz numérica
    mat <- as.matrix(dt_tmp)
    mat[is.na(mat)] <- 0
    km <- kmeans(mat, centers = 4, nstart = 25)
    dataset[, trx_cluster := km$cluster]
  }

  # 10. Promedio de métricas _rank (nuevo insight)
  rank_cols <- grep("_rank$", names(dataset), value = TRUE)
  if(length(rank_cols) > 0)
    dataset[, mean_fin_rank := rowMeans(.SD, na.rm = TRUE), .SDcols = rank_cols]

  # fin nuevas variables

  # valvula de seguridad para evitar valores infinitos
  # paso los infinitos a NULOS
  infinitos <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.infinite(get(.name)))]
  )

  infinitos_qty <- sum(unlist(infinitos))
  if (infinitos_qty > 0) {
    cat(
      "ATENCION, hay", infinitos_qty,
      "valores infinitos en tu dataset. Seran pasados a NA\n"
    )
    dataset[mapply(is.infinite, dataset)] <<- NA
  }


  # valvula de seguridad para evitar valores NaN  que es 0/0
  # paso los NaN a 0 , decision polemica si las hay
  # se invita a asignar un valor razonable segun la semantica del campo creado
  nans <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.nan(get(.name)))]
  )

  nans_qty <- sum(unlist(nans))
  if (nans_qty > 0) {
    cat(
      "ATENCION, hay", nans_qty,
      "valores NaN 0/0 en tu dataset. Seran pasados arbitrariamente a 0\n"
    )

    cat("Si no te gusta la decision, modifica a gusto el programa!\n\n")
    dataset[mapply(is.nan, dataset)] <<- 0
  }

  cat( "fin AgregarVariables_IntraMes()\n")
}

# %%
# agrego las variables intra mes

AgregarVariables_IntraMes(dataset)
# Out:
# inicio AgregarVariables_IntraMes()
# ATENCION, hay 8 valores NaN 0/0 en tu dataset. Seran pasados arbitrariamente a 0
# Si no te gusta la decision, modifica a gusto el programa!
#
# fin AgregarVariables_IntraMes()

# %%
# visualizo las columas del dataset a esta etapa
ncol(dataset)
colnames(dataset)
# Out:
# [1] 56
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "ctrx_quarter_normalizado"
# [35] "foto_mes_formato_fecha"      "mpayroll_sobre_edad"
# [37] "vm_status01"                 "vm_status02"
# [39] "vm_status03"                 "vm_status04"
# [41] "vm_status05"                 "vm_status06"
# [43] "mv_status07"                 "vm_fechaalta"
# [45] "vm_mpagominimo"              "tenure_norm"
# [47] "prod_per_month"              "overdraft_per_trx"
# [49] "call_vs_home_ratio"          "pct_cc_trx"
# [51] "pct_hb_trx"                  "pct_pay_trx"
# [53] "age_minus_tenure"            "new_high_trx"
# [55] "prod_x_maint_fee"            "trx_cluster"

# %% [markdown]
# #### 8.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 8.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
if( !require("Rcpp")) install.packages("Rcpp", repos = "http://cran.us.r-project.org")
require("Rcpp")
# Out:
# Loading required package: Rcpp

# %%
# se calculan para los 6 meses previos el minimo, maximo y
#  tendencia calculada con cuadrados minimos
# la formula de calculo de la tendencia puede verse en
#  https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(Shafer_and_Zhang)/10%3A_Correlation_and_Regression/10.04%3A_The_Least_Squares_Regression_Line
# para la maxíma velocidad esta funcion esta escrita en lenguaje C,
# y no en la porqueria de R o Python

cppFunction("NumericVector fhistC(NumericVector pcolumna, IntegerVector pdesde )
{
  /* Aqui se cargan los valores para la regresion */
  double  x[100] ;
  double  y[100] ;

  int n = pcolumna.size();
  NumericVector out( 5*n );

  for(int i = 0; i < n; i++)
  {
    //lag
    if( pdesde[i]-1 < i )  out[ i + 4*n ]  =  pcolumna[i-1] ;
    else                   out[ i + 4*n ]  =  NA_REAL ;


    int  libre    = 0 ;
    int  xvalor   = 1 ;

    for( int j= pdesde[i]-1;  j<=i; j++ )
    {
       double a = pcolumna[j] ;

       if( !R_IsNA( a ) )
       {
          y[ libre ]= a ;
          x[ libre ]= xvalor ;
          libre++ ;
       }

       xvalor++ ;
    }

    /* Si hay al menos dos valores */
    if( libre > 1 )
    {
      double  xsum  = x[0] ;
      double  ysum  = y[0] ;
      double  xysum = xsum * ysum ;
      double  xxsum = xsum * xsum ;
      double  vmin  = y[0] ;
      double  vmax  = y[0] ;

      for( int h=1; h<libre; h++)
      {
        xsum  += x[h] ;
        ysum  += y[h] ;
        xysum += x[h]*y[h] ;
        xxsum += x[h]*x[h] ;

        if( y[h] < vmin )  vmin = y[h] ;
        if( y[h] > vmax )  vmax = y[h] ;
      }

      out[ i ]  =  (libre*xysum - xsum*ysum)/(libre*xxsum -xsum*xsum) ;
      out[ i + n ]    =  vmin ;
      out[ i + 2*n ]  =  vmax ;
      out[ i + 3*n ]  =  ysum / libre ;
    }
    else
    {
      out[ i       ]  =  NA_REAL ;
      out[ i + n   ]  =  NA_REAL ;
      out[ i + 2*n ]  =  NA_REAL ;
      out[ i + 3*n ]  =  NA_REAL ;
    }
  }

  return  out;
}")

# %%
# calcula la tendencia de las variables cols de los ultimos 6 meses
# la tendencia es la pendiente de la recta que ajusta por cuadrados minimos
# La funcionalidad de ratioavg es autoria de  Daiana Sparta,  UAustral  2021

TendenciaYmuchomas <- function(
    dataset, cols, ventana = 6, tendencia = TRUE,
    minimo = TRUE, maximo = TRUE, promedio = TRUE,
    ratioavg = FALSE, ratiomax = FALSE) {
  gc(verbose= FALSE)
  # Esta es la cantidad de meses que utilizo para la historia
  ventana_regresion <- ventana

  last <- nrow(dataset)

  # creo el vector_desde que indica cada ventana
  # de esta forma se acelera el procesamiento ya que lo hago una sola vez
  vector_ids <- dataset[ , numero_de_cliente ]

  vector_desde <- seq(
    -ventana_regresion + 2,
    nrow(dataset) - ventana_regresion + 1
  )

  vector_desde[1:ventana_regresion] <- 1

  for (i in 2:last) {
    if (vector_ids[i - 1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i - 1]) {
      vector_desde[i] <- vector_desde[i - 1]
    }
  }

  for (campo in cols) {
    nueva_col <- fhistC(dataset[, get(campo)], vector_desde)

    if (tendencia) {
      dataset[, paste0(campo, "_tend", ventana) :=
        nueva_col[(0 * last + 1):(1 * last)]]
    }

    if (minimo) {
      dataset[, paste0(campo, "_min", ventana) :=
        nueva_col[(1 * last + 1):(2 * last)]]
    }

    if (maximo) {
      dataset[, paste0(campo, "_max", ventana) :=
        nueva_col[(2 * last + 1):(3 * last)]]
    }

    if (promedio) {
      dataset[, paste0(campo, "_avg", ventana) :=
        nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratioavg) {
      dataset[, paste0(campo, "_ratioavg", ventana) :=
        get(campo) / nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratiomax) {
      dataset[, paste0(campo, "_ratiomax", ventana) :=
        get(campo) / nueva_col[(2 * last + 1):(3 * last)]]
    }
  }
}

# %%
# Feature Engineering Historico

setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %%
# parametros de Feature Engineering Historico de Tendencias
PARAM$FE_hist$Tendencias$run <- TRUE
PARAM$FE_hist$Tendencias$ventana <- 3
PARAM$FE_hist$Tendencias$tendencia <- TRUE
PARAM$FE_hist$Tendencias$minimo <- FALSE
PARAM$FE_hist$Tendencias$maximo <- FALSE
PARAM$FE_hist$Tendencias$promedio <- FALSE
PARAM$FE_hist$Tendencias$ratioavg <- FALSE
PARAM$FE_hist$Tendencias$ratiomax <- FALSE

# %%
cols_lagueables <- intersect(cols_lagueables, colnames(dataset))
setorder(dataset, numero_de_cliente, foto_mes)

if( PARAM$FE_hist$Tendencias$run) {
    TendenciaYmuchomas(dataset,
    cols = cols_lagueables,
    ventana = PARAM$FE_hist$Tendencias$ventana, # 3 meses de historia
    tendencia = PARAM$FE_hist$Tendencias$tendencia,
    minimo = PARAM$FE_hist$Tendencias$minimo,
    maximo = PARAM$FE_hist$Tendencias$maximo,
    promedio = PARAM$FE_hist$Tendencias$promedio,
    ratioavg = PARAM$FE_hist$Tendencias$ratioavg,
    ratiomax = PARAM$FE_hist$Tendencias$ratiomax
  )
}

# %%
# Feature Engineering Histórico Avanzado
# Combina tendencias, estadísticas y patrones temporales
# Autor: Mejora sobre código de Daiana Sparta, UAustral 2021

FeatureEngineeringHistorico <- function(
    dataset,
    cols,
    id_col = "numero_de_cliente",
    time_col = "foto_mes",
    ventanas = c(3, 6, 12),
    features = list(
      tendencia = TRUE,
      volatilidad = TRUE,           # Desviación estándar
      aceleracion = TRUE,           # Segunda derivada de la tendencia
      estacionalidad = TRUE,        # Patrones cíclicos
      momentum = TRUE,              # Cambio en la tendencia
      percentiles = c(0.25, 0.75),  # Percentiles personalizables
      ratios = TRUE,                # Ratios con promedios y máximos
      cruces_media = TRUE,          # Cruces por encima/debajo del promedio
      rachas = TRUE                 # Longitud de rachas positivas/negativas
    )) {
  require(data.table)
  gc(verbose = FALSE)
  stopifnot(is.data.table(dataset))
  stopifnot(all(c(id_col, time_col) %in% colnames(dataset)))
  stopifnot(all(cols %in% colnames(dataset)))
  setkeyv(dataset, c(id_col, time_col))
  for (ventana in ventanas) {
    cat("Procesando ventana de", ventana, "períodos...\n")
    vector_desde <- crear_ventanas_optimizado(dataset, id_col, ventana)
    for (campo in cols) {
      cat("  - Procesando campo:", campo, "\n")
      valores_hist <- obtener_valores_historicos(dataset, campo, vector_desde, ventana)
      if (features$tendencia) {
        dataset[, paste0(campo, "_tend", ventana) :=
          calcular_tendencia_vectorizada(valores_hist, ventana)]
      }
      if (features$volatilidad) {
        dataset[, paste0(campo, "_vol", ventana) :=
          calcular_volatilidad_vectorizada(valores_hist, ventana)]
      }
      if (features$aceleracion && ventana >= 4) {
        dataset[, paste0(campo, "_acel", ventana) :=
          calcular_aceleracion_vectorizada(valores_hist, ventana)]
      }
      if (features$estacionalidad && ventana >= 12) {
        dataset[, paste0(campo, "_estac", ventana) :=
          calcular_estacionalidad_vectorizada(valores_hist, ventana)]
      }
      if (features$momentum) {
        dataset[, paste0(campo, "_mom", ventana) :=
          calcular_momentum_vectorizada(valores_hist, ventana)]
      }
      if (!is.null(features$percentiles)) {
        for (p in features$percentiles) {
          p_name <- paste0("p", as.integer(p * 100))
          dataset[, paste0(campo, "_", p_name, ventana) :=
            calcular_percentil_vectorizada(valores_hist, ventana, p)]
        }
      }
      if (features$ratios) {
        media_movil <- calcular_promedio_vectorizada(valores_hist, ventana)
        dataset[, paste0(campo, "_ratio_avg", ventana) :=
          ifelse(media_movil == 0, 0, get(campo) / media_movil)]
        max_movil <- calcular_maximo_vectorizada(valores_hist, ventana)
        dataset[, paste0(campo, "_ratio_max", ventana) :=
          ifelse(max_movil == 0, 0, get(campo) / max_movil)]
        min_movil <- calcular_minimo_vectorizada(valores_hist, ventana)
        rango_movil <- max_movil - min_movil
        dataset[, paste0(campo, "_pos_rel", ventana) :=
          ifelse(rango_movil == 0, 0.5, (get(campo) - min_movil) / rango_movil)]
      }
      if (features$cruces_media) {
        media_movil <- calcular_promedio_vectorizada(valores_hist, ventana)
        dataset[, paste0(campo, "_above_avg", ventana) :=
          as.integer(get(campo) > media_movil)]
        dataset[, paste0(campo, "_cruces", ventana) := {
          above <- get(paste0(campo, "_above_avg", ventana))
          c(0, abs(diff(above)))
        }, by = get(id_col)]
      }
      if (features$rachas) {
        dataset[, paste0(campo, "_racha_pos", ventana) :=
          calcular_racha_positiva(valores_hist, ventana)]
        dataset[, paste0(campo, "_racha_neg", ventana) :=
          calcular_racha_negativa(valores_hist, ventana)]
      }
    }
  }
  cols_temp <- grep("_temp_", colnames(dataset), value = TRUE)
  if (length(cols_temp) > 0) {
    dataset[, (cols_temp) := NULL]
  }
  cat("Feature Engineering Histórico completado.\n")
  return(invisible(dataset))
}

# Funciones auxiliares optimizadas
crear_ventanas_optimizado <- function(dataset, id_col, ventana) {
  last <- nrow(dataset)
  vector_ids <- dataset[[id_col]]
  vector_desde <- seq(-ventana + 2, last - ventana + 1)
  vector_desde[1:ventana] <- 1
  for (i in 2:last) {
    if (vector_ids[i-1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i-1]) {
      vector_desde[i] <- vector_desde[i-1]
    }
  }
  return(vector_desde)
}

obtener_valores_historicos <- function(dataset, campo, vector_desde, ventana) {
  return(dataset[[campo]])
}

# Funciones de cálculo vectorizadas (placeholders, deben ser implementadas)
calcular_tendencia_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_volatilidad_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_aceleracion_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_estacionalidad_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_momentum_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_percentil_vectorizada <- function(valores_hist, ventana, percentil) { return(rep(0, length(valores_hist))) }
calcular_promedio_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_maximo_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_minimo_vectorizada <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_racha_positiva <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }
calcular_racha_negativa <- function(valores_hist, ventana) { return(rep(0, length(valores_hist))) }


 FeatureEngineeringHistorico(
   dataset = dataset,
   cols = cols_lagueables,
   ventanas = c(3, 6),
   features = list(
     tendencia = TRUE,
     volatilidad = TRUE,
     aceleracion = TRUE,
     estacionalidad = TRUE,
     momentum = TRUE,
     percentiles = c(0.25, 0.50, 0.75),
     ratios = TRUE,
     cruces_media = TRUE,
     rachas = TRUE # Added rachas = TRUE here
   )
 )
# Out:
# Procesando ventana de 3 períodos...
#   - Procesando campo: internet
#   - Procesando campo: cliente_edad
#   - Procesando campo: cliente_antiguedad
#   - Procesando campo: mrentabilidad
#   - Procesando campo: mrentabilidad_annual
#   - Procesando campo: mcomisiones
#   - Procesando campo: mactivos_margen
#   - Procesando campo: mpasivos_margen
#   - Procesando campo: cproductos
#   - Procesando campo: mcuenta_corriente
#   - Procesando campo: mcaja_ahorro
#   - Procesando campo: cdescubierto_preacordado
#   - Procesando campo: mcuentas_saldo
#   - Procesando campo: ctarjeta_visa_transacciones
#   - Procesando campo: mtarjeta_visa_consumo
#   - Procesando campo: mtarjeta_master_consumo
#   - Procesando campo: mprestamos_personales
#   - Procesando campo: cpayroll_trx
#   - Procesando campo: mpayroll
#   - Procesando campo: ccomisiones_mantenimiento
#   - Procesando campo: ccallcenter_transacciones
#   - Procesando campo: chomebanking_transacciones
#   - Procesando campo: ctrx_quarter
#   - Procesando campo: Master_status
#   - Procesando campo: Master_fechaalta
#   - Procesando campo: Master_mpagominimo
#   - Procesando campo: Visa_status
#   - Procesando campo: Visa_fechaalta
#   - Procesando campo: Visa_mpagominimo
#   - Procesando campo: kmes
#   - Procesando campo: ctrx_quarter_normalizado
#   - Procesando campo: foto_mes_formato_fecha
#   - Procesando campo: mpayroll_sobre_edad
#   - Procesando campo: vm_status01
#   - Procesando campo: vm_status02
#   - Procesando campo: vm_status03
#   - Procesando campo: vm_status04
#   - Procesando campo: vm_status05
#   - Procesando campo: vm_status06
#   - Procesando campo: mv_status07
#   - Procesando campo: vm_fechaalta
#   - Procesando campo: vm_mpagominimo
#   - Procesando campo: tenure_norm
#   - Procesando campo: prod_per_month
#   - Procesando campo: overdraft_per_trx
#   - Procesando campo: call_vs_home_ratio
#   - Procesando campo: pct_cc_trx
#   - Procesando campo: pct_hb_trx
#   - Procesando campo: pct_pay_trx
#   - Procesando campo: age_minus_tenure
#   - Procesando campo: new_high_trx
#   - Procesando campo: prod_x_maint_fee
#   - Procesando campo: trx_cluster
# Procesando ventana de 6 períodos...
#   - Procesando campo: internet
#   - Procesando campo: cliente_edad
#   - Procesando campo: cliente_antiguedad
#   - Procesando campo: mrentabilidad
#   - Procesando campo: mrentabilidad_annual
#   - Procesando campo: mcomisiones
#   - Procesando campo: mactivos_margen
#   - Procesando campo: mpasivos_margen
#   - Procesando campo: cproductos
#   - Procesando campo: mcuenta_corriente
#   - Procesando campo: mcaja_ahorro
#   - Procesando campo: cdescubierto_preacordado
#   - Procesando campo: mcuentas_saldo
#   - Procesando campo: ctarjeta_visa_transacciones
#   - Procesando campo: mtarjeta_visa_consumo
#   - Procesando campo: mtarjeta_master_consumo
#   - Procesando campo: mprestamos_personales
#   - Procesando campo: cpayroll_trx
#   - Procesando campo: mpayroll
#   - Procesando campo: ccomisiones_mantenimiento
#   - Procesando campo: ccallcenter_transacciones
#   - Procesando campo: chomebanking_transacciones
#   - Procesando campo: ctrx_quarter
#   - Procesando campo: Master_status
#   - Procesando campo: Master_fechaalta
#   - Procesando campo: Master_mpagominimo
#   - Procesando campo: Visa_status
#   - Procesando campo: Visa_fechaalta
#   - Procesando campo: Visa_mpagominimo
#   - Procesando campo: kmes
#   - Procesando campo: ctrx_quarter_normalizado
#   - Procesando campo: foto_mes_formato_fecha
#   - Procesando campo: mpayroll_sobre_edad
#   - Procesando campo: vm_status01
#   - Procesando campo: vm_status02
#   - Procesando campo: vm_status03
#   - Procesando campo: vm_status04
#   - Procesando campo: vm_status05
#   - Procesando campo: vm_status06
#   - Procesando campo: mv_status07
#   - Procesando campo: vm_fechaalta
#   - Procesando campo: vm_mpagominimo
#   - Procesando campo: tenure_norm
#   - Procesando campo: prod_per_month
#   - Procesando campo: overdraft_per_trx
#   - Procesando campo: call_vs_home_ratio
#   - Procesando campo: pct_cc_trx
#   - Procesando campo: pct_hb_trx
#   - Procesando campo: pct_pay_trx
#   - Procesando campo: age_minus_tenure
#   - Procesando campo: new_high_trx
#   - Procesando campo: prod_x_maint_fee
#   - Procesando campo: trx_cluster
# Feature Engineering Histórico completado.

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1080
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "internet"
#    [4] "cliente_edad"
#    [5] "cliente_antiguedad"
#    [6] "mrentabilidad"
#    [7] "mrentabilidad_annual"
#    [8] "mcomisiones"
#    [9] "mactivos_margen"
#   [10] "mpasivos_margen"
#   [11] "cproductos"
#   [12] "mcuenta_corriente"
#   [13] "mcaja_ahorro"
#   [14] "cdescubierto_preacordado"
#   [15] "mcuentas_saldo"
#   [16] "ctarjeta_visa_transacciones"
#   [17] "mtarjeta_visa_consumo"
#   [18] "mtarjeta_master_consumo"
#   [19] "mprestamos_personales"
#   [20] "cpayroll_trx"
#   [21] "mpayroll"
#   [22] "ccomisiones_mantenimiento"
#   [23] "ccallcenter_transacciones"
#   [24] "chomebanking_transacciones"
#   [25] "ctrx_quarter"
#   [26] "Master_status"
#   [27] "Master_fechaalta"
#   [28] "Master_mpagominimo"
#   [29] "Visa_status"
#   [30] "Visa_fechaalta"
#   [31] "Visa_mpagominimo"
#   [32] "clase_ternaria"
#   [33] "kmes"
#   [34] "ctrx_quarter_normalizado"
#   [35] "foto_mes_formato_fecha"
#   [36] "mpayroll_sobre_edad"
#   [37] "vm_status01"
#   [38] "vm_status02"
#   [39] "vm_status03"
#   [40] "vm_status04"
#   [41] "vm_status05"
#   [42] "vm_status06"
#   [43] "mv_status07"
#   [44] "vm_fechaalta"
#   [45] "vm_mpagominimo"
#   [46] "tenure_norm"
#   [47] "prod_per_month"
#   [48] "overdraft_per_trx"
#   [49] "call_vs_home_ratio"
#   [50] "pct_cc_trx"
#   [51] "pct_hb_trx"
#   [52] "pct_pay_trx"
#   [53] "age_minus_tenure"
#   [54] "new_high_trx"
#   [55] "prod_x_maint_fee"
#   [56] "trx_cluster"
#   [57] "internet_lag1"
#   [58] "cliente_edad_lag1"
#   [59] "cliente_antiguedad_lag1"
#   [60] "mrentabilidad_lag1"
#   [61] "mrentabilidad_annual_lag1"
#   [62] "mcomisiones_lag1"
#   [63] "mactivos_margen_lag1"
#   [64] "mpasivos_margen_lag1"
#   [65] "cproductos_lag1"
#   [66] "mcuenta_corriente_lag1"
#   [67] "mcaja_ahorro_lag1"
#   [68] "cdescubierto_preacordado_lag1"
#   [69] "mcuentas_saldo_lag1"
#   [70] "ctarjeta_visa_transacciones_lag1"
#   [71] "mtarjeta_visa_consumo_lag1"
#   [72] "mtarjeta_master_consumo_lag1"
#   [73] "mprestamos_personales_lag1"
#   [74] "cpayroll_trx_lag1"
#   [75] "mpayroll_lag1"
#   [76] "ccomisiones_mantenimiento_lag1"
#   [77] "ccallcenter_transacciones_lag1"
#   [78] "chomebanking_transacciones_lag1"
#   [79] "ctrx_quarter_lag1"
#   [80] "Master_status_lag1"
#   [81] "Master_fechaalta_lag1"
#   [82] "Master_mpagominimo_lag1"
#   [83] "Visa_status_lag1"
#   [84] "Visa_fechaalta_lag1"
#   [85] "Visa_mpagominimo_lag1"
#   [86] "kmes_lag1"
#   [87] "ctrx_quarter_normalizado_lag1"
#   [88] "foto_mes_formato_fecha_lag1"
#   [89] "mpayroll_sobre_edad_lag1"
#   [90] "vm_status01_lag1"
#   [91] "vm_status02_lag1"
#   [92] "vm_status03_lag1"
#   [93] "vm_status04_lag1"
#   [94] "vm_status05_lag1"
#   [95] "vm_status06_lag1"
#   [96] "mv_status07_lag1"
#   [97] "vm_fechaalta_lag1"
#   [98] "vm_mpagominimo_lag1"
#   [99] "tenure_norm_lag1"
#  [100] "prod_per_month_lag1"
#  [101] "overdraft_per_trx_lag1"
#  [102] "call_vs_home_ratio_lag1"
#  [103] "pct_cc_trx_lag1"
#  [104] "pct_hb_trx_lag1"
#  [105] "pct_pay_trx_lag1"
#  [106] "age_minus_tenure_lag1"
#  [107] "new_high_trx_lag1"
#  [108] "prod_x_maint_fee_lag1"
#  [109] "trx_cluster_lag1"
#  [110] "internet_lag2"
#  [111] "cliente_edad_lag2"
#  [112] "cliente_antiguedad_lag2"
#  [113] "mrentabilidad_lag2"
#  [114] "mrentabilidad_annual_lag2"
#  [115] "mcomisiones_lag2"
#  [116] "mactivos_margen_lag2"
#  [117] "mpasivos_margen_lag2"
#  [118] "cproductos_lag2"
#  [119] "mcuenta_corriente_lag2"
#  [120] "mcaja_ahorro_lag2"
#  [121] "cdescubierto_preacordado_lag2"
#  [122] "mcuentas_saldo_lag2"
#  [123] "ctarjeta_visa_transacciones_lag2"
#  [124] "mtarjeta_visa_consumo_lag2"
#  [125] "mtarjeta_master_consumo_lag2"
#  [126] "mprestamos_personales_lag2"
#  [127] "cpayroll_trx_lag2"
#  [128] "mpayroll_lag2"
#  [129] "ccomisiones_mantenimiento_lag2"
#  [130] "ccallcenter_transacciones_lag2"
#  [131] "chomebanking_transacciones_lag2"
#  [132] "ctrx_quarter_lag2"
#  [133] "Master_status_lag2"
#  [134] "Master_fechaalta_lag2"
#  [135] "Master_mpagominimo_lag2"
#  [136] "Visa_status_lag2"
#  [137] "Visa_fechaalta_lag2"
#  [138] "Visa_mpagominimo_lag2"
#  [139] "kmes_lag2"
#  [140] "ctrx_quarter_normalizado_lag2"
#  [141] "foto_mes_formato_fecha_lag2"
#  [142] "mpayroll_sobre_edad_lag2"
#  [143] "vm_status01_lag2"
#  [144] "vm_status02_lag2"
#  [145] "vm_status03_lag2"
#  [146] "vm_status04_lag2"
#  [147] "vm_status05_lag2"
#  [148] "vm_status06_lag2"
#  [149] "mv_status07_lag2"
#  [150] "vm_fechaalta_lag2"
#  [151] "vm_mpagominimo_lag2"
#  [152] "tenure_norm_lag2"
#  [153] "prod_per_month_lag2"
#  [154] "overdraft_per_trx_lag2"
#  [155] "call_vs_home_ratio_lag2"
#  [156] "pct_cc_trx_lag2"
#  [157] "pct_hb_trx_lag2"
#  [158] "pct_pay_trx_lag2"
#  [159] "age_minus_tenure_lag2"
#  [160] "new_high_trx_lag2"
#  [161] "prod_x_maint_fee_lag2"
#  [162] "trx_cluster_lag2"
#  [163] "internet_delta1"
#  [164] "internet_delta2"
#  [165] "cliente_edad_delta1"
#  [166] "cliente_edad_delta2"
#  [167] "cliente_antiguedad_delta1"
#  [168] "cliente_antiguedad_delta2"
#  [169] "mrentabilidad_delta1"
#  [170] "mrentabilidad_delta2"
#  [171] "mrentabilidad_annual_delta1"
#  [172] "mrentabilidad_annual_delta2"
#  [173] "mcomisiones_delta1"
#  [174] "mcomisiones_delta2"
#  [175] "mactivos_margen_delta1"
#  [176] "mactivos_margen_delta2"
#  [177] "mpasivos_margen_delta1"
#  [178] "mpasivos_margen_delta2"
#  [179] "cproductos_delta1"
#  [180] "cproductos_delta2"
#  [181] "mcuenta_corriente_delta1"
#  [182] "mcuenta_corriente_delta2"
#  [183] "mcaja_ahorro_delta1"
#  [184] "mcaja_ahorro_delta2"
#  [185] "cdescubierto_preacordado_delta1"
#  [186] "cdescubierto_preacordado_delta2"
#  [187] "mcuentas_saldo_delta1"
#  [188] "mcuentas_saldo_delta2"
#  [189] "ctarjeta_visa_transacciones_delta1"
#  [190] "ctarjeta_visa_transacciones_delta2"
#  [191] "mtarjeta_visa_consumo_delta1"
#  [192] "mtarjeta_visa_consumo_delta2"
#  [193] "mtarjeta_master_consumo_delta1"
#  [194] "mtarjeta_master_consumo_delta2"
#  [195] "mprestamos_personales_delta1"
#  [196] "mprestamos_personales_delta2"
#  [197] "cpayroll_trx_delta1"
#  [198] "cpayroll_trx_delta2"
#  [199] "mpayroll_delta1"
#  [200] "mpayroll_delta2"
#  [201] "ccomisiones_mantenimiento_delta1"
#  [202] "ccomisiones_mantenimiento_delta2"
#  [203] "ccallcenter_transacciones_delta1"
#  [204] "ccallcenter_transacciones_delta2"
#  [205] "chomebanking_transacciones_delta1"
#  [206] "chomebanking_transacciones_delta2"
#  [207] "ctrx_quarter_delta1"
#  [208] "ctrx_quarter_delta2"
#  [209] "Master_status_delta1"
#  [210] "Master_status_delta2"
#  [211] "Master_fechaalta_delta1"
#  [212] "Master_fechaalta_delta2"
#  [213] "Master_mpagominimo_delta1"
#  [214] "Master_mpagominimo_delta2"
#  [215] "Visa_status_delta1"
#  [216] "Visa_status_delta2"
#  [217] "Visa_fechaalta_delta1"
#  [218] "Visa_fechaalta_delta2"
#  [219] "Visa_mpagominimo_delta1"
#  [220] "Visa_mpagominimo_delta2"
#  [221] "kmes_delta1"
#  [222] "kmes_delta2"
#  [223] "ctrx_quarter_normalizado_delta1"
#  [224] "ctrx_quarter_normalizado_delta2"
#  [225] "foto_mes_formato_fecha_delta1"
#  [226] "foto_mes_formato_fecha_delta2"
#  [227] "mpayroll_sobre_edad_delta1"
#  [228] "mpayroll_sobre_edad_delta2"
#  [229] "vm_status01_delta1"
#  [230] "vm_status01_delta2"
#  [231] "vm_status02_delta1"
#  [232] "vm_status02_delta2"
#  [233] "vm_status03_delta1"
#  [234] "vm_status03_delta2"
#  [235] "vm_status04_delta1"
#  [236] "vm_status04_delta2"
#  [237] "vm_status05_delta1"
#  [238] "vm_status05_delta2"
#  [239] "vm_status06_delta1"
#  [240] "vm_status06_delta2"
#  [241] "mv_status07_delta1"
#  [242] "mv_status07_delta2"
#  [243] "vm_fechaalta_delta1"
#  [244] "vm_fechaalta_delta2"
#  [245] "vm_mpagominimo_delta1"
#  [246] "vm_mpagominimo_delta2"
#  [247] "tenure_norm_delta1"
#  [248] "tenure_norm_delta2"
#  [249] "prod_per_month_delta1"
#  [250] "prod_per_month_delta2"
#  [251] "overdraft_per_trx_delta1"
#  [252] "overdraft_per_trx_delta2"
#  [253] "call_vs_home_ratio_delta1"
#  [254] "call_vs_home_ratio_delta2"
#  [255] "pct_cc_trx_delta1"
#  [256] "pct_cc_trx_delta2"
#  [257] "pct_hb_trx_delta1"
#  [258] "pct_hb_trx_delta2"
#  [259] "pct_pay_trx_delta1"
#  [260] "pct_pay_trx_delta2"
#  [261] "age_minus_tenure_delta1"
#  [262] "age_minus_tenure_delta2"
#  [263] "new_high_trx_delta1"
#  [264] "new_high_trx_delta2"
#  [265] "prod_x_maint_fee_delta1"
#  [266] "prod_x_maint_fee_delta2"
#  [267] "trx_cluster_delta1"
#  [268] "trx_cluster_delta2"
#  [269] "internet_tend3"
#  [270] "cliente_edad_tend3"
#  [271] "cliente_antiguedad_tend3"
#  [272] "mrentabilidad_tend3"
#  [273] "mrentabilidad_annual_tend3"
#  [274] "mcomisiones_tend3"
#  [275] "mactivos_margen_tend3"
#  [276] "mpasivos_margen_tend3"
#  [277] "cproductos_tend3"
#  [278] "mcuenta_corriente_tend3"
#  [279] "mcaja_ahorro_tend3"
#  [280] "cdescubierto_preacordado_tend3"
#  [281] "mcuentas_saldo_tend3"
#  [282] "ctarjeta_visa_transacciones_tend3"
#  [283] "mtarjeta_visa_consumo_tend3"
#  [284] "mtarjeta_master_consumo_tend3"
#  [285] "mprestamos_personales_tend3"
#  [286] "cpayroll_trx_tend3"
#  [287] "mpayroll_tend3"
#  [288] "ccomisiones_mantenimiento_tend3"
#  [289] "ccallcenter_transacciones_tend3"
#  [290] "chomebanking_transacciones_tend3"
#  [291] "ctrx_quarter_tend3"
#  [292] "Master_status_tend3"
#  [293] "Master_fechaalta_tend3"
#  [294] "Master_mpagominimo_tend3"
#  [295] "Visa_status_tend3"
#  [296] "Visa_fechaalta_tend3"
#  [297] "Visa_mpagominimo_tend3"
#  [298] "kmes_tend3"
#  [299] "ctrx_quarter_normalizado_tend3"
#  [300] "foto_mes_formato_fecha_tend3"
#  [301] "mpayroll_sobre_edad_tend3"
#  [302] "vm_status01_tend3"
#  [303] "vm_status02_tend3"
#  [304] "vm_status03_tend3"
#  [305] "vm_status04_tend3"
#  [306] "vm_status05_tend3"
#  [307] "vm_status06_tend3"
#  [308] "mv_status07_tend3"
#  [309] "vm_fechaalta_tend3"
#  [310] "vm_mpagominimo_tend3"
#  [311] "tenure_norm_tend3"
#  [312] "prod_per_month_tend3"
#  [313] "overdraft_per_trx_tend3"
#  [314] "call_vs_home_ratio_tend3"
#  [315] "pct_cc_trx_tend3"
#  [316] "pct_hb_trx_tend3"
#  [317] "pct_pay_trx_tend3"
#  [318] "age_minus_tenure_tend3"
#  [319] "new_high_trx_tend3"
#  [320] "prod_x_maint_fee_tend3"
#  [321] "trx_cluster_tend3"
#  [322] "internet_vol3"
#  [323] "internet_mom3"
#  [324] "internet_p253"
#  [325] "internet_p503"
#  [326] "internet_p753"
#  [327] "internet_ratio_avg3"
#  [328] "internet_ratio_max3"
#  [329] "internet_pos_rel3"
#  [330] "internet_above_avg3"
#  [331] "internet_cruces3"
#  [332] "internet_racha_pos3"
#  [333] "internet_racha_neg3"
#  [334] "cliente_edad_vol3"
#  [335] "cliente_edad_mom3"
#  [336] "cliente_edad_p253"
#  [337] "cliente_edad_p503"
#  [338] "cliente_edad_p753"
#  [339] "cliente_edad_ratio_avg3"
#  [340] "cliente_edad_ratio_max3"
#  [341] "cliente_edad_pos_rel3"
#  [342] "cliente_edad_above_avg3"
#  [343] "cliente_edad_cruces3"
#  [344] "cliente_edad_racha_pos3"
#  [345] "cliente_edad_racha_neg3"
#  [346] "cliente_antiguedad_vol3"
#  [347] "cliente_antiguedad_mom3"
#  [348] "cliente_antiguedad_p253"
#  [349] "cliente_antiguedad_p503"
#  [350] "cliente_antiguedad_p753"
#  [351] "cliente_antiguedad_ratio_avg3"
#  [352] "cliente_antiguedad_ratio_max3"
#  [353] "cliente_antiguedad_pos_rel3"
#  [354] "cliente_antiguedad_above_avg3"
#  [355] "cliente_antiguedad_cruces3"
#  [356] "cliente_antiguedad_racha_pos3"
#  [357] "cliente_antiguedad_racha_neg3"
#  [358] "mrentabilidad_vol3"
#  [359] "mrentabilidad_mom3"
#  [360] "mrentabilidad_p253"
#  [361] "mrentabilidad_p503"
#  [362] "mrentabilidad_p753"
#  [363] "mrentabilidad_ratio_avg3"
#  [364] "mrentabilidad_ratio_max3"
#  [365] "mrentabilidad_pos_rel3"
#  [366] "mrentabilidad_above_avg3"
#  [367] "mrentabilidad_cruces3"
#  [368] "mrentabilidad_racha_pos3"
#  [369] "mrentabilidad_racha_neg3"
#  [370] "mrentabilidad_annual_vol3"
#  [371] "mrentabilidad_annual_mom3"
#  [372] "mrentabilidad_annual_p253"
#  [373] "mrentabilidad_annual_p503"
#  [374] "mrentabilidad_annual_p753"
#  [375] "mrentabilidad_annual_ratio_avg3"
#  [376] "mrentabilidad_annual_ratio_max3"
#  [377] "mrentabilidad_annual_pos_rel3"
#  [378] "mrentabilidad_annual_above_avg3"
#  [379] "mrentabilidad_annual_cruces3"
#  [380] "mrentabilidad_annual_racha_pos3"
#  [381] "mrentabilidad_annual_racha_neg3"
#  [382] "mcomisiones_vol3"
#  [383] "mcomisiones_mom3"
#  [384] "mcomisiones_p253"
#  [385] "mcomisiones_p503"
#  [386] "mcomisiones_p753"
#  [387] "mcomisiones_ratio_avg3"
#  [388] "mcomisiones_ratio_max3"
#  [389] "mcomisiones_pos_rel3"
#  [390] "mcomisiones_above_avg3"
#  [391] "mcomisiones_cruces3"
#  [392] "mcomisiones_racha_pos3"
#  [393] "mcomisiones_racha_neg3"
#  [394] "mactivos_margen_vol3"
#  [395] "mactivos_margen_mom3"
#  [396] "mactivos_margen_p253"
#  [397] "mactivos_margen_p503"
#  [398] "mactivos_margen_p753"
#  [399] "mactivos_margen_ratio_avg3"
#  [400] "mactivos_margen_ratio_max3"
#  [401] "mactivos_margen_pos_rel3"
#  [402] "mactivos_margen_above_avg3"
#  [403] "mactivos_margen_cruces3"
#  [404] "mactivos_margen_racha_pos3"
#  [405] "mactivos_margen_racha_neg3"
#  [406] "mpasivos_margen_vol3"
#  [407] "mpasivos_margen_mom3"
#  [408] "mpasivos_margen_p253"
#  [409] "mpasivos_margen_p503"
#  [410] "mpasivos_margen_p753"
#  [411] "mpasivos_margen_ratio_avg3"
#  [412] "mpasivos_margen_ratio_max3"
#  [413] "mpasivos_margen_pos_rel3"
#  [414] "mpasivos_margen_above_avg3"
#  [415] "mpasivos_margen_cruces3"
#  [416] "mpasivos_margen_racha_pos3"
#  [417] "mpasivos_margen_racha_neg3"
#  [418] "cproductos_vol3"
#  [419] "cproductos_mom3"
#  [420] "cproductos_p253"
#  [421] "cproductos_p503"
#  [422] "cproductos_p753"
#  [423] "cproductos_ratio_avg3"
#  [424] "cproductos_ratio_max3"
#  [425] "cproductos_pos_rel3"
#  [426] "cproductos_above_avg3"
#  [427] "cproductos_cruces3"
#  [428] "cproductos_racha_pos3"
#  [429] "cproductos_racha_neg3"
#  [430] "mcuenta_corriente_vol3"
#  [431] "mcuenta_corriente_mom3"
#  [432] "mcuenta_corriente_p253"
#  [433] "mcuenta_corriente_p503"
#  [434] "mcuenta_corriente_p753"
#  [435] "mcuenta_corriente_ratio_avg3"
#  [436] "mcuenta_corriente_ratio_max3"
#  [437] "mcuenta_corriente_pos_rel3"
#  [438] "mcuenta_corriente_above_avg3"
#  [439] "mcuenta_corriente_cruces3"
#  [440] "mcuenta_corriente_racha_pos3"
#  [441] "mcuenta_corriente_racha_neg3"
#  [442] "mcaja_ahorro_vol3"
#  [443] "mcaja_ahorro_mom3"
#  [444] "mcaja_ahorro_p253"
#  [445] "mcaja_ahorro_p503"
#  [446] "mcaja_ahorro_p753"
#  [447] "mcaja_ahorro_ratio_avg3"
#  [448] "mcaja_ahorro_ratio_max3"
#  [449] "mcaja_ahorro_pos_rel3"
#  [450] "mcaja_ahorro_above_avg3"
#  [451] "mcaja_ahorro_cruces3"
#  [452] "mcaja_ahorro_racha_pos3"
#  [453] "mcaja_ahorro_racha_neg3"
#  [454] "cdescubierto_preacordado_vol3"
#  [455] "cdescubierto_preacordado_mom3"
#  [456] "cdescubierto_preacordado_p253"
#  [457] "cdescubierto_preacordado_p503"
#  [458] "cdescubierto_preacordado_p753"
#  [459] "cdescubierto_preacordado_ratio_avg3"
#  [460] "cdescubierto_preacordado_ratio_max3"
#  [461] "cdescubierto_preacordado_pos_rel3"
#  [462] "cdescubierto_preacordado_above_avg3"
#  [463] "cdescubierto_preacordado_cruces3"
#  [464] "cdescubierto_preacordado_racha_pos3"
#  [465] "cdescubierto_preacordado_racha_neg3"
#  [466] "mcuentas_saldo_vol3"
#  [467] "mcuentas_saldo_mom3"
#  [468] "mcuentas_saldo_p253"
#  [469] "mcuentas_saldo_p503"
#  [470] "mcuentas_saldo_p753"
#  [471] "mcuentas_saldo_ratio_avg3"
#  [472] "mcuentas_saldo_ratio_max3"
#  [473] "mcuentas_saldo_pos_rel3"
#  [474] "mcuentas_saldo_above_avg3"
#  [475] "mcuentas_saldo_cruces3"
#  [476] "mcuentas_saldo_racha_pos3"
#  [477] "mcuentas_saldo_racha_neg3"
#  [478] "ctarjeta_visa_transacciones_vol3"
#  [479] "ctarjeta_visa_transacciones_mom3"
#  [480] "ctarjeta_visa_transacciones_p253"
#  [481] "ctarjeta_visa_transacciones_p503"
#  [482] "ctarjeta_visa_transacciones_p753"
#  [483] "ctarjeta_visa_transacciones_ratio_avg3"
#  [484] "ctarjeta_visa_transacciones_ratio_max3"
#  [485] "ctarjeta_visa_transacciones_pos_rel3"
#  [486] "ctarjeta_visa_transacciones_above_avg3"
#  [487] "ctarjeta_visa_transacciones_cruces3"
#  [488] "ctarjeta_visa_transacciones_racha_pos3"
#  [489] "ctarjeta_visa_transacciones_racha_neg3"
#  [490] "mtarjeta_visa_consumo_vol3"
#  [491] "mtarjeta_visa_consumo_mom3"
#  [492] "mtarjeta_visa_consumo_p253"
#  [493] "mtarjeta_visa_consumo_p503"
#  [494] "mtarjeta_visa_consumo_p753"
#  [495] "mtarjeta_visa_consumo_ratio_avg3"
#  [496] "mtarjeta_visa_consumo_ratio_max3"
#  [497] "mtarjeta_visa_consumo_pos_rel3"
#  [498] "mtarjeta_visa_consumo_above_avg3"
#  [499] "mtarjeta_visa_consumo_cruces3"
#  [500] "mtarjeta_visa_consumo_racha_pos3"
#  [501] "mtarjeta_visa_consumo_racha_neg3"
#  [502] "mtarjeta_master_consumo_vol3"
#  [503] "mtarjeta_master_consumo_mom3"
#  [504] "mtarjeta_master_consumo_p253"
#  [505] "mtarjeta_master_consumo_p503"
#  [506] "mtarjeta_master_consumo_p753"
#  [507] "mtarjeta_master_consumo_ratio_avg3"
#  [508] "mtarjeta_master_consumo_ratio_max3"
#  [509] "mtarjeta_master_consumo_pos_rel3"
#  [510] "mtarjeta_master_consumo_above_avg3"
#  [511] "mtarjeta_master_consumo_cruces3"
#  [512] "mtarjeta_master_consumo_racha_pos3"
#  [513] "mtarjeta_master_consumo_racha_neg3"
#  [514] "mprestamos_personales_vol3"
#  [515] "mprestamos_personales_mom3"
#  [516] "mprestamos_personales_p253"
#  [517] "mprestamos_personales_p503"
#  [518] "mprestamos_personales_p753"
#  [519] "mprestamos_personales_ratio_avg3"
#  [520] "mprestamos_personales_ratio_max3"
#  [521] "mprestamos_personales_pos_rel3"
#  [522] "mprestamos_personales_above_avg3"
#  [523] "mprestamos_personales_cruces3"
#  [524] "mprestamos_personales_racha_pos3"
#  [525] "mprestamos_personales_racha_neg3"
#  [526] "cpayroll_trx_vol3"
#  [527] "cpayroll_trx_mom3"
#  [528] "cpayroll_trx_p253"
#  [529] "cpayroll_trx_p503"
#  [530] "cpayroll_trx_p753"
#  [531] "cpayroll_trx_ratio_avg3"
#  [532] "cpayroll_trx_ratio_max3"
#  [533] "cpayroll_trx_pos_rel3"
#  [534] "cpayroll_trx_above_avg3"
#  [535] "cpayroll_trx_cruces3"
#  [536] "cpayroll_trx_racha_pos3"
#  [537] "cpayroll_trx_racha_neg3"
#  [538] "mpayroll_vol3"
#  [539] "mpayroll_mom3"
#  [540] "mpayroll_p253"
#  [541] "mpayroll_p503"
#  [542] "mpayroll_p753"
#  [543] "mpayroll_ratio_avg3"
#  [544] "mpayroll_ratio_max3"
#  [545] "mpayroll_pos_rel3"
#  [546] "mpayroll_above_avg3"
#  [547] "mpayroll_cruces3"
#  [548] "mpayroll_racha_pos3"
#  [549] "mpayroll_racha_neg3"
#  [550] "ccomisiones_mantenimiento_vol3"
#  [551] "ccomisiones_mantenimiento_mom3"
#  [552] "ccomisiones_mantenimiento_p253"
#  [553] "ccomisiones_mantenimiento_p503"
#  [554] "ccomisiones_mantenimiento_p753"
#  [555] "ccomisiones_mantenimiento_ratio_avg3"
#  [556] "ccomisiones_mantenimiento_ratio_max3"
#  [557] "ccomisiones_mantenimiento_pos_rel3"
#  [558] "ccomisiones_mantenimiento_above_avg3"
#  [559] "ccomisiones_mantenimiento_cruces3"
#  [560] "ccomisiones_mantenimiento_racha_pos3"
#  [561] "ccomisiones_mantenimiento_racha_neg3"
#  [562] "ccallcenter_transacciones_vol3"
#  [563] "ccallcenter_transacciones_mom3"
#  [564] "ccallcenter_transacciones_p253"
#  [565] "ccallcenter_transacciones_p503"
#  [566] "ccallcenter_transacciones_p753"
#  [567] "ccallcenter_transacciones_ratio_avg3"
#  [568] "ccallcenter_transacciones_ratio_max3"
#  [569] "ccallcenter_transacciones_pos_rel3"
#  [570] "ccallcenter_transacciones_above_avg3"
#  [571] "ccallcenter_transacciones_cruces3"
#  [572] "ccallcenter_transacciones_racha_pos3"
#  [573] "ccallcenter_transacciones_racha_neg3"
#  [574] "chomebanking_transacciones_vol3"
#  [575] "chomebanking_transacciones_mom3"
#  [576] "chomebanking_transacciones_p253"
#  [577] "chomebanking_transacciones_p503"
#  [578] "chomebanking_transacciones_p753"
#  [579] "chomebanking_transacciones_ratio_avg3"
#  [580] "chomebanking_transacciones_ratio_max3"
#  [581] "chomebanking_transacciones_pos_rel3"
#  [582] "chomebanking_transacciones_above_avg3"
#  [583] "chomebanking_transacciones_cruces3"
#  [584] "chomebanking_transacciones_racha_pos3"
#  [585] "chomebanking_transacciones_racha_neg3"
#  [586] "ctrx_quarter_vol3"
#  [587] "ctrx_quarter_mom3"
#  [588] "ctrx_quarter_p253"
#  [589] "ctrx_quarter_p503"
#  [590] "ctrx_quarter_p753"
#  [591] "ctrx_quarter_ratio_avg3"
#  [592] "ctrx_quarter_ratio_max3"
#  [593] "ctrx_quarter_pos_rel3"
#  [594] "ctrx_quarter_above_avg3"
#  [595] "ctrx_quarter_cruces3"
#  [596] "ctrx_quarter_racha_pos3"
#  [597] "ctrx_quarter_racha_neg3"
#  [598] "Master_status_vol3"
#  [599] "Master_status_mom3"
#  [600] "Master_status_p253"
#  [601] "Master_status_p503"
#  [602] "Master_status_p753"
#  [603] "Master_status_ratio_avg3"
#  [604] "Master_status_ratio_max3"
#  [605] "Master_status_pos_rel3"
#  [606] "Master_status_above_avg3"
#  [607] "Master_status_cruces3"
#  [608] "Master_status_racha_pos3"
#  [609] "Master_status_racha_neg3"
#  [610] "Master_fechaalta_vol3"
#  [611] "Master_fechaalta_mom3"
#  [612] "Master_fechaalta_p253"
#  [613] "Master_fechaalta_p503"
#  [614] "Master_fechaalta_p753"
#  [615] "Master_fechaalta_ratio_avg3"
#  [616] "Master_fechaalta_ratio_max3"
#  [617] "Master_fechaalta_pos_rel3"
#  [618] "Master_fechaalta_above_avg3"
#  [619] "Master_fechaalta_cruces3"
#  [620] "Master_fechaalta_racha_pos3"
#  [621] "Master_fechaalta_racha_neg3"
#  [622] "Master_mpagominimo_vol3"
#  [623] "Master_mpagominimo_mom3"
#  [624] "Master_mpagominimo_p253"
#  [625] "Master_mpagominimo_p503"
#  [626] "Master_mpagominimo_p753"
#  [627] "Master_mpagominimo_ratio_avg3"
#  [628] "Master_mpagominimo_ratio_max3"
#  [629] "Master_mpagominimo_pos_rel3"
#  [630] "Master_mpagominimo_above_avg3"
#  [631] "Master_mpagominimo_cruces3"
#  [632] "Master_mpagominimo_racha_pos3"
#  [633] "Master_mpagominimo_racha_neg3"
#  [634] "Visa_status_vol3"
#  [635] "Visa_status_mom3"
#  [636] "Visa_status_p253"
#  [637] "Visa_status_p503"
#  [638] "Visa_status_p753"
#  [639] "Visa_status_ratio_avg3"
#  [640] "Visa_status_ratio_max3"
#  [641] "Visa_status_pos_rel3"
#  [642] "Visa_status_above_avg3"
#  [643] "Visa_status_cruces3"
#  [644] "Visa_status_racha_pos3"
#  [645] "Visa_status_racha_neg3"
#  [646] "Visa_fechaalta_vol3"
#  [647] "Visa_fechaalta_mom3"
#  [648] "Visa_fechaalta_p253"
#  [649] "Visa_fechaalta_p503"
#  [650] "Visa_fechaalta_p753"
#  [651] "Visa_fechaalta_ratio_avg3"
#  [652] "Visa_fechaalta_ratio_max3"
#  [653] "Visa_fechaalta_pos_rel3"
#  [654] "Visa_fechaalta_above_avg3"
#  [655] "Visa_fechaalta_cruces3"
#  [656] "Visa_fechaalta_racha_pos3"
#  [657] "Visa_fechaalta_racha_neg3"
#  [658] "Visa_mpagominimo_vol3"
#  [659] "Visa_mpagominimo_mom3"
#  [660] "Visa_mpagominimo_p253"
#  [661] "Visa_mpagominimo_p503"
#  [662] "Visa_mpagominimo_p753"
#  [663] "Visa_mpagominimo_ratio_avg3"
#  [664] "Visa_mpagominimo_ratio_max3"
#  [665] "Visa_mpagominimo_pos_rel3"
#  [666] "Visa_mpagominimo_above_avg3"
#  [667] "Visa_mpagominimo_cruces3"
#  [668] "Visa_mpagominimo_racha_pos3"
#  [669] "Visa_mpagominimo_racha_neg3"
#  [670] "kmes_vol3"
#  [671] "kmes_mom3"
#  [672] "kmes_p253"
#  [673] "kmes_p503"
#  [674] "kmes_p753"
#  [675] "kmes_ratio_avg3"
#  [676] "kmes_ratio_max3"
#  [677] "kmes_pos_rel3"
#  [678] "kmes_above_avg3"
#  [679] "kmes_cruces3"
#  [680] "kmes_racha_pos3"
#  [681] "kmes_racha_neg3"
#  [682] "ctrx_quarter_normalizado_vol3"
#  [683] "ctrx_quarter_normalizado_mom3"
#  [684] "ctrx_quarter_normalizado_p253"
#  [685] "ctrx_quarter_normalizado_p503"
#  [686] "ctrx_quarter_normalizado_p753"
#  [687] "ctrx_quarter_normalizado_ratio_avg3"
#  [688] "ctrx_quarter_normalizado_ratio_max3"
#  [689] "ctrx_quarter_normalizado_pos_rel3"
#  [690] "ctrx_quarter_normalizado_above_avg3"
#  [691] "ctrx_quarter_normalizado_cruces3"
#  [692] "ctrx_quarter_normalizado_racha_pos3"
#  [693] "ctrx_quarter_normalizado_racha_neg3"
#  [694] "foto_mes_formato_fecha_vol3"
#  [695] "foto_mes_formato_fecha_mom3"
#  [696] "foto_mes_formato_fecha_p253"
#  [697] "foto_mes_formato_fecha_p503"
#  [698] "foto_mes_formato_fecha_p753"
#  [699] "foto_mes_formato_fecha_ratio_avg3"
#  [700] "foto_mes_formato_fecha_ratio_max3"
#  [701] "foto_mes_formato_fecha_pos_rel3"
#  [702] "foto_mes_formato_fecha_above_avg3"
#  [703] "foto_mes_formato_fecha_cruces3"
#  [704] "foto_mes_formato_fecha_racha_pos3"
#  [705] "foto_mes_formato_fecha_racha_neg3"
#  [706] "mpayroll_sobre_edad_vol3"
#  [707] "mpayroll_sobre_edad_mom3"
#  [708] "mpayroll_sobre_edad_p253"
#  [709] "mpayroll_sobre_edad_p503"
#  [710] "mpayroll_sobre_edad_p753"
#  [711] "mpayroll_sobre_edad_ratio_avg3"
#  [712] "mpayroll_sobre_edad_ratio_max3"
#  [713] "mpayroll_sobre_edad_pos_rel3"
#  [714] "mpayroll_sobre_edad_above_avg3"
#  [715] "mpayroll_sobre_edad_cruces3"
#  [716] "mpayroll_sobre_edad_racha_pos3"
#  [717] "mpayroll_sobre_edad_racha_neg3"
#  [718] "vm_status01_vol3"
#  [719] "vm_status01_mom3"
#  [720] "vm_status01_p253"
#  [721] "vm_status01_p503"
#  [722] "vm_status01_p753"
#  [723] "vm_status01_ratio_avg3"
#  [724] "vm_status01_ratio_max3"
#  [725] "vm_status01_pos_rel3"
#  [726] "vm_status01_above_avg3"
#  [727] "vm_status01_cruces3"
#  [728] "vm_status01_racha_pos3"
#  [729] "vm_status01_racha_neg3"
#  [730] "vm_status02_vol3"
#  [731] "vm_status02_mom3"
#  [732] "vm_status02_p253"
#  [733] "vm_status02_p503"
#  [734] "vm_status02_p753"
#  [735] "vm_status02_ratio_avg3"
#  [736] "vm_status02_ratio_max3"
#  [737] "vm_status02_pos_rel3"
#  [738] "vm_status02_above_avg3"
#  [739] "vm_status02_cruces3"
#  [740] "vm_status02_racha_pos3"
#  [741] "vm_status02_racha_neg3"
#  [742] "vm_status03_vol3"
#  [743] "vm_status03_mom3"
#  [744] "vm_status03_p253"
#  [745] "vm_status03_p503"
#  [746] "vm_status03_p753"
#  [747] "vm_status03_ratio_avg3"
#  [748] "vm_status03_ratio_max3"
#  [749] "vm_status03_pos_rel3"
#  [750] "vm_status03_above_avg3"
#  [751] "vm_status03_cruces3"
#  [752] "vm_status03_racha_pos3"
#  [753] "vm_status03_racha_neg3"
#  [754] "vm_status04_vol3"
#  [755] "vm_status04_mom3"
#  [756] "vm_status04_p253"
#  [757] "vm_status04_p503"
#  [758] "vm_status04_p753"
#  [759] "vm_status04_ratio_avg3"
#  [760] "vm_status04_ratio_max3"
#  [761] "vm_status04_pos_rel3"
#  [762] "vm_status04_above_avg3"
#  [763] "vm_status04_cruces3"
#  [764] "vm_status04_racha_pos3"
#  [765] "vm_status04_racha_neg3"
#  [766] "vm_status05_vol3"
#  [767] "vm_status05_mom3"
#  [768] "vm_status05_p253"
#  [769] "vm_status05_p503"
#  [770] "vm_status05_p753"
#  [771] "vm_status05_ratio_avg3"
#  [772] "vm_status05_ratio_max3"
#  [773] "vm_status05_pos_rel3"
#  [774] "vm_status05_above_avg3"
#  [775] "vm_status05_cruces3"
#  [776] "vm_status05_racha_pos3"
#  [777] "vm_status05_racha_neg3"
#  [778] "vm_status06_vol3"
#  [779] "vm_status06_mom3"
#  [780] "vm_status06_p253"
#  [781] "vm_status06_p503"
#  [782] "vm_status06_p753"
#  [783] "vm_status06_ratio_avg3"
#  [784] "vm_status06_ratio_max3"
#  [785] "vm_status06_pos_rel3"
#  [786] "vm_status06_above_avg3"
#  [787] "vm_status06_cruces3"
#  [788] "vm_status06_racha_pos3"
#  [789] "vm_status06_racha_neg3"
#  [790] "mv_status07_vol3"
#  [791] "mv_status07_mom3"
#  [792] "mv_status07_p253"
#  [793] "mv_status07_p503"
#  [794] "mv_status07_p753"
#  [795] "mv_status07_ratio_avg3"
#  [796] "mv_status07_ratio_max3"
#  [797] "mv_status07_pos_rel3"
#  [798] "mv_status07_above_avg3"
#  [799] "mv_status07_cruces3"
#  [800] "mv_status07_racha_pos3"
#  [801] "mv_status07_racha_neg3"
#  [802] "vm_fechaalta_vol3"
#  [803] "vm_fechaalta_mom3"
#  [804] "vm_fechaalta_p253"
#  [805] "vm_fechaalta_p503"
#  [806] "vm_fechaalta_p753"
#  [807] "vm_fechaalta_ratio_avg3"
#  [808] "vm_fechaalta_ratio_max3"
#  [809] "vm_fechaalta_pos_rel3"
#  [810] "vm_fechaalta_above_avg3"
#  [811] "vm_fechaalta_cruces3"
#  [812] "vm_fechaalta_racha_pos3"
#  [813] "vm_fechaalta_racha_neg3"
#  [814] "vm_mpagominimo_vol3"
#  [815] "vm_mpagominimo_mom3"
#  [816] "vm_mpagominimo_p253"
#  [817] "vm_mpagominimo_p503"
#  [818] "vm_mpagominimo_p753"
#  [819] "vm_mpagominimo_ratio_avg3"
#  [820] "vm_mpagominimo_ratio_max3"
#  [821] "vm_mpagominimo_pos_rel3"
#  [822] "vm_mpagominimo_above_avg3"
#  [823] "vm_mpagominimo_cruces3"
#  [824] "vm_mpagominimo_racha_pos3"
#  [825] "vm_mpagominimo_racha_neg3"
#  [826] "tenure_norm_vol3"
#  [827] "tenure_norm_mom3"
#  [828] "tenure_norm_p253"
#  [829] "tenure_norm_p503"
#  [830] "tenure_norm_p753"
#  [831] "tenure_norm_ratio_avg3"
#  [832] "tenure_norm_ratio_max3"
#  [833] "tenure_norm_pos_rel3"
#  [834] "tenure_norm_above_avg3"
#  [835] "tenure_norm_cruces3"
#  [836] "tenure_norm_racha_pos3"
#  [837] "tenure_norm_racha_neg3"
#  [838] "prod_per_month_vol3"
#  [839] "prod_per_month_mom3"
#  [840] "prod_per_month_p253"
#  [841] "prod_per_month_p503"
#  [842] "prod_per_month_p753"
#  [843] "prod_per_month_ratio_avg3"
#  [844] "prod_per_month_ratio_max3"
#  [845] "prod_per_month_pos_rel3"
#  [846] "prod_per_month_above_avg3"
#  [847] "prod_per_month_cruces3"
#  [848] "prod_per_month_racha_pos3"
#  [849] "prod_per_month_racha_neg3"
#  [850] "overdraft_per_trx_vol3"
#  [851] "overdraft_per_trx_mom3"
#  [852] "overdraft_per_trx_p253"
#  [853] "overdraft_per_trx_p503"
#  [854] "overdraft_per_trx_p753"
#  [855] "overdraft_per_trx_ratio_avg3"
#  [856] "overdraft_per_trx_ratio_max3"
#  [857] "overdraft_per_trx_pos_rel3"
#  [858] "overdraft_per_trx_above_avg3"
#  [859] "overdraft_per_trx_cruces3"
#  [860] "overdraft_per_trx_racha_pos3"
#  [861] "overdraft_per_trx_racha_neg3"
#  [862] "call_vs_home_ratio_vol3"
#  [863] "call_vs_home_ratio_mom3"
#  [864] "call_vs_home_ratio_p253"
#  [865] "call_vs_home_ratio_p503"
#  [866] "call_vs_home_ratio_p753"
#  [867] "call_vs_home_ratio_ratio_avg3"
#  [868] "call_vs_home_ratio_ratio_max3"
#  [869] "call_vs_home_ratio_pos_rel3"
#  [870] "call_vs_home_ratio_above_avg3"
#  [871] "call_vs_home_ratio_cruces3"
#  [872] "call_vs_home_ratio_racha_pos3"
#  [873] "call_vs_home_ratio_racha_neg3"
#  [874] "pct_cc_trx_vol3"
#  [875] "pct_cc_trx_mom3"
#  [876] "pct_cc_trx_p253"
#  [877] "pct_cc_trx_p503"
#  [878] "pct_cc_trx_p753"
#  [879] "pct_cc_trx_ratio_avg3"
#  [880] "pct_cc_trx_ratio_max3"
#  [881] "pct_cc_trx_pos_rel3"
#  [882] "pct_cc_trx_above_avg3"
#  [883] "pct_cc_trx_cruces3"
#  [884] "pct_cc_trx_racha_pos3"
#  [885] "pct_cc_trx_racha_neg3"
#  [886] "pct_hb_trx_vol3"
#  [887] "pct_hb_trx_mom3"
#  [888] "pct_hb_trx_p253"
#  [889] "pct_hb_trx_p503"
#  [890] "pct_hb_trx_p753"
#  [891] "pct_hb_trx_ratio_avg3"
#  [892] "pct_hb_trx_ratio_max3"
#  [893] "pct_hb_trx_pos_rel3"
#  [894] "pct_hb_trx_above_avg3"
#  [895] "pct_hb_trx_cruces3"
#  [896] "pct_hb_trx_racha_pos3"
#  [897] "pct_hb_trx_racha_neg3"
#  [898] "pct_pay_trx_vol3"
#  [899] "pct_pay_trx_mom3"
#  [900] "pct_pay_trx_p253"
#  [901] "pct_pay_trx_p503"
#  [902] "pct_pay_trx_p753"
#  [903] "pct_pay_trx_ratio_avg3"
#  [904] "pct_pay_trx_ratio_max3"
#  [905] "pct_pay_trx_pos_rel3"
#  [906] "pct_pay_trx_above_avg3"
#  [907] "pct_pay_trx_cruces3"
#  [908] "pct_pay_trx_racha_pos3"
#  [909] "pct_pay_trx_racha_neg3"
#  [910] "age_minus_tenure_vol3"
#  [911] "age_minus_tenure_mom3"
#  [912] "age_minus_tenure_p253"
#  [913] "age_minus_tenure_p503"
#  [914] "age_minus_tenure_p753"
#  [915] "age_minus_tenure_ratio_avg3"
#  [916] "age_minus_tenure_ratio_max3"
#  [917] "age_minus_tenure_pos_rel3"
#  [918] "age_minus_tenure_above_avg3"
#  [919] "age_minus_tenure_cruces3"
#  [920] "age_minus_tenure_racha_pos3"
#  [921] "age_minus_tenure_racha_neg3"
#  [922] "new_high_trx_vol3"
#  [923] "new_high_trx_mom3"
#  [924] "new_high_trx_p253"
#  [925] "new_high_trx_p503"
#  [926] "new_high_trx_p753"
#  [927] "new_high_trx_ratio_avg3"
#  [928] "new_high_trx_ratio_max3"
#  [929] "new_high_trx_pos_rel3"
#  [930] "new_high_trx_above_avg3"
#  [931] "new_high_trx_cruces3"
#  [932] "new_high_trx_racha_pos3"
#  [933] "new_high_trx_racha_neg3"
#  [934] "prod_x_maint_fee_vol3"
#  [935] "prod_x_maint_fee_mom3"
#  [936] "prod_x_maint_fee_p253"
#  [937] "prod_x_maint_fee_p503"
#  [938] "prod_x_maint_fee_p753"
#  [939] "prod_x_maint_fee_ratio_avg3"
#  [940] "prod_x_maint_fee_ratio_max3"
#  [941] "prod_x_maint_fee_pos_rel3"
#  [942] "prod_x_maint_fee_above_avg3"
#  [943] "prod_x_maint_fee_cruces3"
#  [944] "prod_x_maint_fee_racha_pos3"
#  [945] "prod_x_maint_fee_racha_neg3"
#  [946] "trx_cluster_vol3"
#  [947] "trx_cluster_mom3"
#  [948] "trx_cluster_p253"
#  [949] "trx_cluster_p503"
#  [950] "trx_cluster_p753"
#  [951] "trx_cluster_ratio_avg3"
#  [952] "trx_cluster_ratio_max3"
#  [953] "trx_cluster_pos_rel3"
#  [954] "trx_cluster_above_avg3"
#  [955] "trx_cluster_cruces3"
#  [956] "trx_cluster_racha_pos3"
#  [957] "trx_cluster_racha_neg3"
#  [958] "internet_tend6"
#  [959] "internet_vol6"
#  [960] "internet_acel6"
#  [961] "internet_mom6"
#  [962] "internet_p256"
#  [963] "internet_p506"
#  [964] "internet_p756"
#  [965] "internet_ratio_avg6"
#  [966] "internet_ratio_max6"
#  [967] "internet_pos_rel6"
#  [968] "internet_above_avg6"
#  [969] "internet_cruces6"
#  [970] "internet_racha_pos6"
#  [971] "internet_racha_neg6"
#  [972] "cliente_edad_tend6"
#  [973] "cliente_edad_vol6"
#  [974] "cliente_edad_acel6"
#  [975] "cliente_edad_mom6"
#  [976] "cliente_edad_p256"
#  [977] "cliente_edad_p506"
#  [978] "cliente_edad_p756"
#  [979] "cliente_edad_ratio_avg6"
#  [980] "cliente_edad_ratio_max6"
#  [981] "cliente_edad_pos_rel6"
#  [982] "cliente_edad_above_avg6"
#  [983] "cliente_edad_cruces6"
#  [984] "cliente_edad_racha_pos6"
#  [985] "cliente_edad_racha_neg6"
#  [986] "cliente_antiguedad_tend6"
#  [987] "cliente_antiguedad_vol6"
#  [988] "cliente_antiguedad_acel6"
#  [989] "cliente_antiguedad_mom6"
#  [990] "cliente_antiguedad_p256"
#  [991] "cliente_antiguedad_p506"
#  [992] "cliente_antiguedad_p756"
#  [993] "cliente_antiguedad_ratio_avg6"
#  [994] "cliente_antiguedad_ratio_max6"
#  [995] "cliente_antiguedad_pos_rel6"
#  [996] "cliente_antiguedad_above_avg6"
#  [997] "cliente_antiguedad_cruces6"
3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 8.3.2 Modelado

# %% [markdown]
# #### 8.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  con un undersampling de los CONTINUA del 2% por un tema de velocidad
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  8.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.02, upper = 0.3),
  makeNumericParam("feature_fraction", lower = 0.05, upper = 0.90),
  makeNumericParam("coverage", lower = 0.05, upper = 1.0), # nuevo
  makeNumericParam("leaf_size", lower = 0.001, upper = 0.2) # nuevo
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  message(format(Sys.time(), "%a %b %d %X %Y"))

  # uno la lista de hiperparametros : fijos + variables
  param_completo <- c(PARAM$lgbm$param_fijos, x)

  # hago la transformacion de leaf_size y  coverage
  if( "leaf_size"  %in% names(param_completo) &
      "coverage"  %in% names(param_completo)
  )
  {
    # primero defino el tamaño de las hojas
    param_completo$min_data_in_leaf <- pmax( 1,  round( nrow(dtrain) * param_completo$leaf_size )  )
    # luego la cantidad de hojas en funcion del valor anterior, el coverage, y la cantidad de registros
    param_completo$num_leaves <- pmin( 131072,
      pmax( 8,  round( ( param_completo$coverage * nrow( dtrain ) / param_completo$min_data_in_leaf ) ) ))
  }


  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Warning message in mboContinue("HT.RDATA"):
# “Tuning ended with term.iter. No need to continue. Simply returning stored result.”

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

require("data.table") # Ensure data.table is loaded

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# order by AUC (y) descending, then num_iterations descending
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
best_result <- tb_bayesiana[1]

# Add print statements for debugging
print("Best result from tb_bayesiana:")
print(best_result)

num_leaves_val = best_result$num_leaves
min_data_in_leaf_val = best_result$min_data_in_leaf
num_iterations_val = best_result$extras[[1]]$num_iterations

print(paste("num_leaves_val:", num_leaves_val))
print(paste("min_data_in_leaf_val:", min_data_in_leaf_val))
print(paste("num_iterations_val:", num_iterations_val))


PARAM$out$lgbm$mejores_hiperparametros <- list(
  num_leaves = num_leaves_val,
  min_data_in_leaf = min_data_in_leaf_val,
  num_iterations = num_iterations_val
)

print("Final hyperparameters assigned to PARAM:")
print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
# [1] "Best result from tb_bayesiana:"
#    learning_rate feature_fraction  coverage   leaf_size         y   dob   eol
#            <num>            <num>     <num>       <num>     <num> <int> <int>
# 1:    0.03118073        0.2143678 0.3538628 0.001001762 0.9453889    27    NA
#    error.message exec.time            ei error.model train.time prop.type
#           <char>     <num>         <num>      <char>      <num>    <char>
# 1:          <NA>   239.901 -3.600873e-05        <NA>      0.042 infill_ei
#    propose.time          se    mean num_iterations
#           <num>       <num>   <num>          <int>
# 1:         0.36 0.001573559 0.94032            598
# [1] "num_leaves_val: "
# [1] "min_data_in_leaf_val: "
# [1] "num_iterations_val: "
# [1] "Final hyperparameters assigned to PARAM:"
# $num_leaves
# NULL
#
# $min_data_in_leaf
# NULL
#
# $num_iterations
# NULL

# %% [markdown]
# ### 8.3.3 Produccion Semillerio

# %% [markdown]
# ### Final Training Semillerio
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# #### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# Construct param_final explicitly using extracted values
param_final <- fijos
param_final$num_leaves <- PARAM$out$lgbm$mejores_hiperparametros$num_leaves
param_final$min_data_in_leaf <- PARAM$out$lgbm$mejores_hiperparametros$min_data_in_leaf
param_final$num_iterations <- PARAM$out$lgbm$mejores_hiperparametros$num_iterations


# Add print statements for debugging
print("Contents of PARAM$out$lgbm$mejores_hiperparametros:")
print(PARAM$out$lgbm$mejores_hiperparametros)
print("Contents of param_final before training:")
print(param_final)
# Out:
# [1] "Contents of PARAM$out$lgbm$mejores_hiperparametros:"
# $num_leaves
# NULL
#
# $min_data_in_leaf
# NULL
#
# $num_iterations
# NULL
#
# [1] "Contents of param_final before training:"
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] TRUE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $verbosity
# [1] -100
#
# $force_row_wise
# [1] TRUE
#
# $seed
# [1] 100003
#
# $max_bin
# [1] 31

# %% [markdown]
# #### Training  Semillerio
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %% [markdown]
# ### Aqui va cuantas semillas utilizo para el semillerio

# %%
# semillerio
PARAM$FT$semillerio <- 50  # cantidad de semillas

# %%
# semillerio
if(!require("primes")) install.packages("primes")
require("primes")

# %%
# semillerio
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
# me quedo con PARAM$semillerio  primos al azar
PARAM$FT$semillas <- sample(primos)[seq(PARAM$FT$semillerio)]

cat( PARAM$FT$semillas)
# Out:
#
# 16547 3.217071e-02 3.217071e-02 3.217071e-02 3.217071e-02 3.217071e-02
# 16548 3.296130e-02 3.296130e-02 3.296130e-02 3.296130e-02 3.296130e-02
# 16549 2.704936e-02 2.704936e-02 2.704936e-02 2.704936e-02 2.704936e-02
# 16550 3.067118e-02 3.067118e-02 3.067118e-02 3.067118e-02 3.067118e-02
# 16551 7.199383e-04 7.199383e-04 7.199383e-04 7.199383e-04 7.199383e-04

# %%
# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos

fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "labo-i-2025-rosario-analista-jr"   o  la original "labo-i-2025-rosario"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-rosario-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0(
    "./kaggle/KAS",
    PARAM$experimento, "_",
    "s", length(PARAM$FT$semillas), "_",
    envios, ".csv"
  )

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
  "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial
# Successfully submitted to LaboI 2025 Rosario Gerencial

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Jul 20 04:54:46 PM 2025"

# %%
# Inspect the tb_bayesiana object
print(tb_bayesiana)
print(colnames(tb_bayesiana))
# Out:
#      learning_rate feature_fraction   coverage   leaf_size         y   dob
#              <num>            <num>      <num>       <num>     <num> <int>
#   1:    0.03118073        0.2143678 0.35386285 0.001001762 0.9453889    27
#   2:    0.03349926        0.2766102 0.26511127 0.001003433 0.9450439    30
#   3:    0.02872870        0.5230241 0.45775142 0.001007266 0.9450179    64
#   4:    0.02992303        0.5415816 0.42595061 0.001013292 0.9448713    70
#   5:    0.03515003        0.4034965 0.24005431 0.001104784 0.9445765    93
#  ---
# 112:    0.27941899        0.8392683 0.85805999 0.070778706 0.9213344     0
# 113:    0.03292186        0.4444948 0.70280485 0.172360368 0.9208676     0
# 114:    0.22977152        0.3489506 0.56665898 0.052079983 0.9205492     0
# 115:    0.24238211        0.2256841 0.42158839 0.190240731 0.9195380     0
# 116:    0.29756818        0.8998237 0.07269406 0.001045827 0.9177050    12
#        eol error.message exec.time            ei error.model train.time
#      <int>        <char>     <num>         <num>      <char>      <num>
#   1:    NA          <NA>   239.901 -3.600873e-05        <NA>      0.042
#   2:    NA          <NA>   222.240 -1.104792e-03        <NA>      0.082
#   3:    NA          <NA>   420.573 -2.143911e-04        <NA>      0.158
#   4:    NA          <NA>   346.892 -3.163818e-04        <NA>      0.160
#   5:    NA          <NA>   394.060 -1.799704e-03        <NA>      0.116
#  ---
# 112:    NA          <NA>    57.815            NA        <NA>         NA
# 113:    NA          <NA>   375.719            NA        <NA>         NA
# 114:    NA          <NA>   196.120            NA        <NA>         NA
# 115:    NA          <NA>    79.585            NA        <NA>         NA
# 116:    NA          <NA>   102.081 -2.264177e-05        <NA>      0.073
#       prop.type propose.time           se      mean num_iterations
#          <char>        <num>        <num>     <num>          <int>
#   1:  infill_ei        0.360 0.0015735588 0.9403200            598
#   2:  infill_ei        0.597 0.0009592318 0.9464253            491
#   3:  infill_ei        0.695 0.0037685663 0.9408923            610
#   4:  infill_ei        0.453 0.0008162899 0.9453702            471
#   5:  infill_ei        0.488 0.0020342895 0.9469239            820
#  ---
# 112: initdesign           NA           NA        NA            144
# 113: initdesign           NA           NA        NA           1115
# 114: initdesign           NA           NA        NA            450
# 115: initdesign           NA           NA        NA            175
# 116:  infill_ei        0.551 0.0059814758 0.9291586            310
#  [1] "learning_rate"    "feature_fraction" "coverage"         "leaf_size"
#  [5] "y"                "dob"              "eol"              "error.message"
#  [9] "exec.time"        "ei"               "error.model"      "train.time"
# [13] "prop.type"        "propose.time"     "se"               "mean"
# [17] "num_iterations"
